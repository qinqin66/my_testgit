# %%
import netCDF4
import xarray as xr
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cf
import matplotlib.pyplot as plt
import numpy as np
import salem

# %%
data=salem.open_wrf_dataset('/mnt/e/wrf_tibet/pre_run/input/geo_em.d01.nc')

# %%
data2=salem.open_wrf_dataset('/mnt/e/wrf_tibet/pre_run/input/geo_em.d01_new.nc')

# %%
data.HGT_M.salem.quick_map()

# %%
data2.HGT_M.salem.quick_map()

# %%
import netCDF4
import xarray as xr
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cf
import matplotlib.pyplot as plt
import numpy as np

# %%
data1=xr.open_dataset('/mnt/e/wrf_tibet/test/3/geo_em.d01.nc')
data2=xr.open_dataset('/mnt/e/wrf_tibet/test/3/geo_em.d02.nc')

# %%
wrfout=xr.open_dataset('/mnt/e/wrf_tibet/test/wrfout_d01_2018-01-01_12_00_00')

# %%
data1
# Out:
# <xarray.Dataset>
# Dimensions:     (Time: 1, land_cat: 21, month: 12, soil_cat: 16, south_north: 199, south_north_stag: 200, west_east: 179, west_east_stag: 180)
# Dimensions without coordinates: Time, land_cat, month, soil_cat, south_north, south_north_stag, west_east, west_east_stag
# Data variables:
#     Times       (Time) |S19 ...
#     XLAT_M      (Time, south_north, west_east) float32 ...
#     XLONG_M     (Time, south_north, west_east) float32 ...
#     XLAT_V      (Time, south_north_stag, west_east) float32 ...
#     XLONG_V     (Time, south_north_stag, west_east) float32 ...
#     XLAT_U      (Time, south_north, west_east_stag) float32 ...
#     XLONG_U     (Time, south_north, west_east_stag) float32 ...
#     CLAT        (Time, south_north, west_east) float32 ...
#     CLONG       (Time, south_north, west_east) float32 ...
#     MAPFAC_M    (Time, south_north, west_east) float32 ...
#     MAPFAC_V    (Time, south_north_stag, west_east) float32 ...
# ...

# %%
data2['HGT_M'].plot()

# %%
wrfout['Q2'][0].plot()

# %%
wrfout['T'][0][0].mean()
# Out:
# <xarray.DataArray 'T' ()>
# array(-16.133337, dtype=float32)
# Coordinates:
#     XTIME    datetime64[ns] 2018-01-01T12:00:00

# %%
wrfout['T'][16][0].mean()
# Out:
# <xarray.DataArray 'T' ()>
# array(-15.350162, dtype=float32)
# Coordinates:
#     XTIME    datetime64[ns] 2018-01-03T12:00:00

# %%
data1['LAI'].plot()

# %%
data2['LU_INDEX'].plot()

# %%
wrfout['U'][0][0].plot()

# %%
data1['T'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/gis3/lib/python3.8/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1171         try:
# -> 1172             variable = self._variables[name]
#    1173         except KeyError:
#
# KeyError: 'T'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-98ad05bc8ea5> in <module>
# ----> 1 data1['T'].plot()
#
# ~/anaconda3/envs/gis3/lib/python3.8/site-packages/xarray/core/dataset.py in __getitem__(self, key)
#    1270
#    1271         if hashable(key):
# -> 1272             return self._construct_dataarray(key)
#    1273         else:
#    1274             return self._copy_listed(np.asarray(key))
#
# ...

# %%
data2['HGT_M'].plot()

# %%
import netCDF4 as nc
import xarray as xr
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cf
import matplotlib.pyplot as plt
import numpy as np

from osgeo import gdal,osr,ogr
import matplotlib.pyplot as plt
import gdal
import rasterio

from netCDF4 import Dataset
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
import cartopy.crs as crs
from cartopy.feature import NaturalEarthFeature
import numpy as np
import pandas as pd
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.geoaxes import GeoAxes
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from mpl_toolkits.axes_grid1 import AxesGrid
# import seaborn as sns 
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import cartopy.io.shapereader as shpreader
import matplotlib.colors as colors
from wrf import (to_np, getvar, smooth2d, get_cartopy, cartopy_xlim,
                 cartopy_ylim, latlon_coords)
import geopandas

# %%
# mask tibet shp
import salem

# %%
control_wrf=salem.open_wrf_dataset('/mnt/e/wrf_tibet/test/pre_test2003summer/wrfout_tibet_2003_summer_control')

# %%
control=xr.open_dataset('/mnt/e/wrf_tibet/test/pre_test2003summer/wrfout_tibet_2003_summer_control')

# %%
data=Dataset('/mnt/e/wrf_tibet/test/pre_test2003summer/wrfout_tibet_2003_summer_control')

# %%
shp = geopandas.read_file('/mnt/f/data/shp/Tibet/TP_WGS84.shp')
control_wrf_lai=control_wrf.LAI
control_wrf_lai_tibet=control_wrf_lai.salem.roi(shape=shp)

# %%
control_wrf_lai_tibet
# Out:
# <xarray.DataArray 'LAI' (time: 721, south_north: 171, west_east: 231)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]], dtype=float32)
# Coordinates:
#     lat          (south_north, west_east) float32 8.361839 ... 48.142765
#     lon          (south_north, west_east) float32 82.610504 ... 161.61536
#     xtime        (time) datetime64[ns] 2003-06-01T12:00:00 ... 2003-08-30T12:...
#   * time         (time) datetime64[ns] 2003-06-01T12:00:00 ... 2003-08-30T12:...
#   * west_east    (west_east) float64 -3.45e+06 -3.42e+06 ... 3.42e+06 3.45e+06
#   * south_north  (south_north) float64 -2.55e+06 -2.52e+06 ... 2.52e+06 2.55e+06
# Attributes:
#     FieldType:    104
#     MemoryOrder:  XY
#     description:  LEAF AREA INDEX
#     units:        m-2/m-2
#     stagger:
#     pyproj_srs:   +proj=lcc +lat_0=35.1800193786621 +lon_0=110 +lat_1=30 +lat...

# %%
dse = salem.open_xr_dataset(salem.get_demo_file('era_interim_tibet.nc'))

# %%
#control_wrf_lai_tibet = control_wrf_lai_tibet.salem.transform(dse)

# %%
control_wrf_lai_tibet_monthly=control_wrf_lai_tibet.groupby('time.month').mean()

# %%
control_wrf_lai_tibet_monthly
# Out:
# <xarray.DataArray 'LAI' (month: 3, south_north: 171, west_east: 231)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]], dtype=float32)
# Coordinates:
#     lat          (south_north, west_east) float32 8.361839 ... 48.142765
#     lon          (south_north, west_east) float32 82.610504 ... 161.61536
#   * west_east    (west_east) float64 -3.45e+06 -3.42e+06 ... 3.42e+06 3.45e+06
#   * south_north  (south_north) float64 -2.55e+06 -2.52e+06 ... 2.52e+06 2.55e+06
#   * month        (month) int64 6 7 8

# %%
control_wrf_lai_tibet_monthly.sel(month=6)
# Out:
# <xarray.DataArray 'LAI' (south_north: 171, west_east: 231)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
# Coordinates:
#     lat          (south_north, west_east) float32 8.361839 ... 48.142765
#     lon          (south_north, west_east) float32 82.610504 ... 161.61536
#   * west_east    (west_east) float64 -3.45e+06 -3.42e+06 ... 3.42e+06 3.45e+06
#   * south_north  (south_north) float64 -2.55e+06 -2.52e+06 ... 2.52e+06 2.55e+06
#     month        int64 6

# %%
lai_modis.read(1)
# Out:
# array([[ 7.73027143,  7.50670778,  7.10270916, ...,  6.76574818,
#          7.7419971 ,  7.1424991 ],
#        [ 5.44882553,  5.04688997,  4.52457998, ...,  7.02588346,
#          8.3194698 ,  7.54948234],
#        [ 4.7246196 ,  4.48688007,  4.20060891, ...,  6.70884989,
#          7.23984924,  6.72442308],
#        ...,
#        [ 4.03215214,  4.44243728,  4.84058633, ..., 21.76804235,
#         21.1856982 , 21.23574146],
#        [ 4.44519667,  4.81731415,  5.19133518, ..., 22.20936798,
#         21.85295039, 21.8353791 ],
#        [ 4.81164724,  5.12632081,  5.46402818, ..., 22.94056076,
#         22.96543666, 22.9008859 ]])

# %%
control_wrf_lai_tibet_monthly
# Out:
# <xarray.DataArray 'LAI' (month: 3, south_north: 171, west_east: 231)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]], dtype=float32)
# Coordinates:
#     lat          (south_north, west_east) float32 8.361839 ... 48.142765
#     lon          (south_north, west_east) float32 82.610504 ... 161.61536
#   * west_east    (west_east) float64 -3.45e+06 -3.42e+06 ... 3.42e+06 3.45e+06
#   * south_north  (south_north) float64 -2.55e+06 -2.52e+06 ... 2.52e+06 2.55e+06
#   * month        (month) int64 6 7 8

# %%
lai_7=control_wrf_lai_tibet_monthly.sel(month=6)*1000
lai_7
# Out:
# <xarray.DataArray 'LAI' (south_north: 171, west_east: 231)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
# Coordinates:
#     lat          (south_north, west_east) float32 8.361839 ... 48.142765
#     lon          (south_north, west_east) float32 82.610504 ... 161.61536
#   * west_east    (west_east) float64 -3.45e+06 -3.42e+06 ... 3.42e+06 3.45e+06
#   * south_north  (south_north) float64 -2.55e+06 -2.52e+06 ... 2.52e+06 2.55e+06
#     month        int64 6

# %%
tibet=salem.open_xr_dataset('/mnt/e/wrf_tibet/data/verify_data/lai_tibet_2003_aug_30km.tif')
tibet_lai=tibet.salem.roi(shape=shp)

# %%
lai_7.plot()

# %%
tibet_lai.data.plot()

# %%
lai_7_to_array=np.array(lai_7)
lai_7_to_array
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)

# %%
# import modis lai
lai_modis=rasterio.open('/mnt/e/wrf_tibet/data/verify_data/lai_tibet_2003_july_30km.tif')
lai_modis.read(1)
# Out:
# array([[ 7.73027143,  7.50670778,  7.10270916, ...,  6.76574818,
#          7.7419971 ,  7.1424991 ],
#        [ 5.44882553,  5.04688997,  4.52457998, ...,  7.02588346,
#          8.3194698 ,  7.54948234],
#        [ 4.7246196 ,  4.48688007,  4.20060891, ...,  6.70884989,
#          7.23984924,  6.72442308],
#        ...,
#        [ 4.03215214,  4.44243728,  4.84058633, ..., 21.76804235,
#         21.1856982 , 21.23574146],
#        [ 4.44519667,  4.81731415,  5.19133518, ..., 22.20936798,
#         21.85295039, 21.8353791 ],
#        [ 4.81164724,  5.12632081,  5.46402818, ..., 22.94056076,
#         22.96543666, 22.9008859 ]])

# %%
plt.imshow(lai_modis.read(1))

# %%
from rasterio.plot import show
show(lai_modis.read(), transform=lai_modis.transform)
# Out:
# <AxesSubplot:>

# %%
lai_7
# Out:
# <xarray.DataArray 'LAI' (south_north: 171, west_east: 231)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
# Coordinates:
#     lat          (south_north, west_east) float32 8.361839 ... 48.142765
#     lon          (south_north, west_east) float32 82.610504 ... 161.61536
#   * west_east    (west_east) float64 -3.45e+06 -3.42e+06 ... 3.42e+06 3.45e+06
#   * south_north  (south_north) float64 -2.55e+06 -2.52e+06 ... 2.52e+06 2.55e+06
#     month        int64 7

# %%
lai_modis.read(1)
# Out:
# array([[ 7.73027143,  7.50670778,  7.10270916, ...,  6.76574818,
#          7.7419971 ,  7.1424991 ],
#        [ 5.44882553,  5.04688997,  4.52457998, ...,  7.02588346,
#          8.3194698 ,  7.54948234],
#        [ 4.7246196 ,  4.48688007,  4.20060891, ...,  6.70884989,
#          7.23984924,  6.72442308],
#        ...,
#        [ 4.03215214,  4.44243728,  4.84058633, ..., 21.76804235,
#         21.1856982 , 21.23574146],
#        [ 4.44519667,  4.81731415,  5.19133518, ..., 22.20936798,
#         21.85295039, 21.8353791 ],
#        [ 4.81164724,  5.12632081,  5.46402818, ..., 22.94056076,
#         22.96543666, 22.9008859 ]])

# %%
ncfile = Dataset("/mnt/e/wrf_tibet/test/tibet/wrfinput_d01")
slp = getvar(ncfile, "HGT")
lats, lons = latlon_coords(slp)
smooth=smooth2d(slp, 3, cenweight=4)
cartopy_xlim(smooth)
# Out:
# [-3450000.2772787847, 3449999.084971637]

# %%
import cartopy.crs as ccrs
from cartopy.mpl.geoaxes import GeoAxes
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid
import numpy as np


def draw_var(input_data,title_text):
    ncfile = Dataset("/mnt/e/wrf_tibet/test/tibet/wrfinput_d01")
    slp = getvar(ncfile, "HGT")
    smooth=smooth2d(slp, 3, cenweight=4)
    projection = ccrs.PlateCarree()
    axes_class = (GeoAxes,
                  dict(map_projection=get_cartopy(slp)))
    lats, lons = latlon_coords(slp)
    data=smooth2d(input_data, 3, cenweight=4)

    fig = plt.figure(figsize=(12,6))
    ax = AxesGrid(fig, 111, axes_class=axes_class,
                    nrows_ncols=(1, 1),
                    axes_pad=0.6,
                    cbar_location='right',
                    cbar_mode='single',
                    cbar_pad=0.2,
                    cbar_size='3%',
                    label_mode='')  # note the empty label_mode

# Download and add the states and coastlines
    states = NaturalEarthFeature(category="cultural", scale="50m",
                             facecolor="none",
                             name="admin_1_states_provinces_shp")
#    ax[0].add_feature(states, linewidth=.5, edgecolor="black")
#    ax[0].coastlines('50m', linewidth=0.8)
#ax.set_xticks(np.linspace(-150,-50, 3), crs=ccrs.cart_proj())
#ax.set_xticklabels(np.linspace(-150,-50, 3),fontsize=16)

#Make the contour outlines and filled contours for the smoothed sea level
# pressure.
#plt.contour(to_np(lons), to_np(lats), to_np(smooth_slp), 10, colors="black",
#            transform=crs.PlateCarree())
    p=ax[0].contourf(to_np(lons), to_np(lats), to_np(data), 50,
            vmin=0,
            vmax=2000,
            transform=crs.PlateCarree(),
            cmap='YlGn'
                    )
#             cmap=terrain_map
    cb=ax.cbar_axes[0].colorbar(p,ticks=[0,1000,2000,3000,4000,5000])
    cb.ax.tick_params(axis='y',direction='in')
    cb.ax.set_yticklabels([0,1000,2000,3000,4000,5000],fontsize=9)
    cb.set_label_text(r'$\Delta$LST(℃)',fontsize=18)

# Set the map bounds
#    ax[0].set_xlim(cartopy_xlim(smooth))
#    ax[0].set_ylim(cartopy_ylim(smooth))

# Add the gridlines
#    ax[0].gridlines(color="black", linestyle="dotted")
    ax[0].set_title(title_text,fontsize=18)
#    plt.title("Effects of Tibetan grass on temperature(model level 1) in JJA,2003")
    plt.show()

# %%
import matplotlib.pyplot as plt
import rasterio
from rasterio import plot

import cartopy
import cartopy.crs as ccrs
da=xr.open_rasterio('/mnt/e/wrf_tibet/data/verify_data/lai_tibet_2003_july_30km.tif')
da_tibet=da.salem.roi(shape=shp)

# %%
projection = ccrs.PlateCarree()
axes_class = (GeoAxes,
              dict(map_projection=get_cartopy(slp)))
da=da_tibet
lats, lons = da.y,da.x
data=da
fig = plt.figure(figsize=(12,6))
ax = AxesGrid(fig, 111, axes_class=axes_class,
                nrows_ncols=(1, 1),
                axes_pad=0.6,
                cbar_location='right',
                cbar_mode='single',
                cbar_pad=0.2,
                cbar_size='3%',
                label_mode='')  # note the empty label_mode

# Download and add the states and coastlines
states = NaturalEarthFeature(category="cultural", scale="50m",
                             facecolor="none",
                             name="admin_1_states_provinces_shp")
ax[0].add_feature(states, linewidth=.5, edgecolor="black")
ax[0].coastlines('50m', linewidth=0.8)
#ax.set_xticks(np.linspace(-150,-50, 3), crs=ccrs.cart_proj())
#ax.set_xticklabels(np.linspace(-150,-50, 3),fontsize=16)

#Make the contour outlines and filled contours for the smoothed sea level
# pressure.
#plt.contour(to_np(lons), to_np(lats), to_np(smooth_slp), 10, colors="black",
#            transform=crs.PlateCarree())
p=ax[0].contourf(lons, lats, data[0], 50,
        vmin=0,
        vmax=30,
        transform=crs.PlateCarree(),
        cmap='YlGn'
                )
#             cmap=terrain_map
cb=ax.cbar_axes[0].colorbar(p,ticks=[0,10,20,30,40,50])
cb.ax.tick_params(axis='y',direction='in')
cb.ax.set_yticklabels([0,10,20,30,40,50],fontsize=9)
cb.set_label_text(r'$\Delta$LST(℃)',fontsize=18)

# Set the map bounds
ax[0].set_xlim(cartopy_xlim(smooth))
ax[0].set_ylim(cartopy_ylim(smooth))

# Add the gridlines
ax[0].gridlines(color="black", linestyle="dotted")
#ax[0].set_title(title_text,fontsize=18)
#    plt.title("Effects of Tibetan grass on temperature(model level 1) in JJA,2003")
plt.show()
# Out:
# <ipython-input-396-17cb163e62d0>:37: MatplotlibDeprecationWarning: Since 3.2, mpl_toolkits's own colorbar implementation is deprecated; it will be removed two minor releases later.  Set the 'mpl_toolkits.legacy_colorbar' rcParam to False to use Matplotlib's default colorbar implementation and suppress this deprecation warning.
#   cb=ax.cbar_axes[0].colorbar(p,ticks=[0,10,20,30,40,50])

# %%
projection = ccrs.PlateCarree()
axes_class = (GeoAxes,
              dict(map_projection=get_cartopy(slp)))
da=lai_7
lats, lons = latlon_coords(slp)
data=lai_7
fig = plt.figure(figsize=(12,6))
ax = AxesGrid(fig, 111, axes_class=axes_class,
                nrows_ncols=(1, 1),
                axes_pad=0.6,
                cbar_location='right',
                cbar_mode='single',
                cbar_pad=0.2,
                cbar_size='3%',
                label_mode='')  # note the empty label_mode

# Download and add the states and coastlines
states = NaturalEarthFeature(category="cultural", scale="50m",
                             facecolor="none",
                             name="admin_1_states_provinces_shp")
ax[0].add_feature(states, linewidth=.5, edgecolor="black")
ax[0].coastlines('50m', linewidth=0.8)
#ax.set_xticks(np.linspace(-150,-50, 3), crs=ccrs.cart_proj())
#ax.set_xticklabels(np.linspace(-150,-50, 3),fontsize=16)

#Make the contour outlines and filled contours for the smoothed sea level
# pressure.
#plt.contour(to_np(lons), to_np(lats), to_np(smooth_slp), 10, colors="black",
#            transform=crs.PlateCarree())
p=ax[0].contourf(lons, lats, data, 50,
        vmin=0,
        vmax=3000,
        transform=crs.PlateCarree(),
        cmap='YlGn'
                )
#             cmap=terrain_map
cb=ax.cbar_axes[0].colorbar(p,ticks=[0,1000,2000,3000,4000,5000])
cb.ax.tick_params(axis='y',direction='in')
cb.ax.set_yticklabels([0,1000,2000,3000,4000,5000],fontsize=9)
cb.set_label_text(r'$\Delta$LST(℃)',fontsize=18)

# Set the map bounds
ax[0].set_xlim(cartopy_xlim(smooth))
ax[0].set_ylim(cartopy_ylim(smooth))

# Add the gridlines
ax[0].gridlines(color="black", linestyle="dotted")
#ax[0].set_title(title_text,fontsize=18)
#    plt.title("Effects of Tibetan grass on temperature(model level 1) in JJA,2003")
plt.show()
# Out:
# <ipython-input-395-bc8ae3585968>:37: MatplotlibDeprecationWarning: Since 3.2, mpl_toolkits's own colorbar implementation is deprecated; it will be removed two minor releases later.  Set the 'mpl_toolkits.legacy_colorbar' rcParam to False to use Matplotlib's default colorbar implementation and suppress this deprecation warning.
#   cb=ax.cbar_axes[0].colorbar(p,ticks=[0,1000,2000,3000,4000,5000])

# %%
cartopy_xlim(smooth)
# Out:
# [-3450000.2772787847, 3449999.084971637]

# %%
lai_7_to_array.shape
# Out:
# (171, 231)

# %%
lai_model=lai_7_to_array.reshape(171*231,1)
np.array(pd.DataFrame(lai_model).dropna()).shape
# Out:
# (2809, 1)

# %%
lai_sate=np.array(da_tibet[0]).reshape(52*117,1)
np.array(pd.DataFrame(lai_sate).dropna()).shape
# Out:
# (3457, 1)

# %%
np.array(pd.DataFrame(np.array(da_tibet[0])).dropna())
# Out:
# array([], shape=(0, 117), dtype=float64)

# %%
da_tibet[0]
# Out:
# <xarray.DataArray (y: 52, x: 117)>
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan, 4.52457998, ...,        nan,        nan,
#                nan],
#        [       nan, 4.48688007, 4.20060891, ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]])
# Coordinates:
#     band     int64 1
#   * y        (y) float64 39.75 39.48 39.21 38.94 ... 26.81 26.55 26.28 26.01
#   * x        (x) float64 73.44 73.71 73.98 74.25 ... 103.9 104.2 104.4 104.7
# Attributes:
#     transform:      (0.26949458523585645, 0.0, 73.30252718415295, 0.0, -0.269...
#     crs:            +init=epsg:4326
#     res:            (0.26949458523585645, 0.26949458523585645)
#     is_tiled:       1
#     nodatavals:     (nan,)
#     scales:         (1.0,)
#     offsets:        (0.0,)
#     descriptions:   ('Lai_500m',)
#     AREA_OR_POINT:  Area
#     pyproj_srs:     +proj=longlat +datum=WGS84 +no_defs

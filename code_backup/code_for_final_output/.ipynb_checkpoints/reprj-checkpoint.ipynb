# %%
import salem

# %%
dse = salem.open_xr_dataset(salem.get_demo_file('era_interim_tibet.nc'))

# %%
ds = salem.open_xr_dataset('/mnt/e/wrf_tibet/test/pre_test2003summer/wrfout_tibet_2003_summer_control')

# %%
ds.sel(Time=0)
# Out:
# <xarray.Dataset>
# Dimensions:                (bottom_top: 32, bottom_top_stag: 33, seed_dim_stag: 2, snow_layers_stag: 3, snso_layers_stag: 7, soil_layers_stag: 4, south_north: 171, south_north_stag: 172, west_east: 231, west_east_stag: 232)
# Coordinates:
#     XLAT                   (south_north, west_east) float32 ...
#     XLONG                  (south_north, west_east) float32 ...
#     XTIME                  datetime64[ns] 2003-06-01T12:00:00
#     XLAT_U                 (south_north, west_east_stag) float32 ...
#     XLONG_U                (south_north, west_east_stag) float32 ...
#     XLAT_V                 (south_north_stag, west_east) float32 ...
#     XLONG_V                (south_north_stag, west_east) float32 ...
#   * west_east              (west_east) float64 -3.45e+06 -3.42e+06 ... 3.45e+06
#   * south_north            (south_north) float64 -2.55e+06 ... 2.55e+06
# ...

# %%
lu=ds.sel(Time=0).LU_INDEX

# %%
t2=ds.sel(Time=0).T2

# %%
dse = salem.open_xr_dataset(salem.get_demo_file('era_interim_tibet.nc'))

# %%
t2_reprj=t2.salem.transform(dse.t2m.isel(time=0))

# %%
t2_reprj.salem.quick_map()

# %%
npp=salem.open_xr_dataset('/mnt/e/wrf_tibet/data/verify_data/lai_tibet_2003_july_30km.tif')

# %%
a=npp.data.salem.transform(t2)

# %%
npp.data.salem.quick_map()

# %%
a
# Out:
# <xarray.DataArray 'T2' (y: 52, x: 117)>
# array([[282.56372, 279.89487, 280.55695, ..., 295.94376, 295.94376,
#         295.6483 ],
#        [279.6364 , 279.6364 , 278.74863, ..., 297.25446, 296.69162,
#         295.7482 ],
#        [277.92215, 278.0841 , 278.31873, ..., 297.90082, 297.21262,
#         296.13165],
#        ...,
#        [      nan,       nan,       nan, ..., 291.18878, 291.30487,
#         291.67438],
#        [      nan,       nan,       nan, ..., 290.98935, 291.2835 ,
#         291.89725],
#        [      nan,       nan,       nan, ..., 291.10892, 291.54468,
#         292.3331 ]], dtype=float32)
# Coordinates:
#     XTIME    datetime64[ns] 2003-06-01T12:00:00
#   * x        (x) float64 73.3 73.57 73.84 74.11 ... 103.8 104.0 104.3 104.6
#   * y        (y) float64 39.89 39.62 39.35 39.08 ... 26.95 26.68 26.41 26.14
# Attributes:
#     FieldType:    104
#     MemoryOrder:  XY
#     description:  TEMP at 2 M
#     units:        K
#     stagger:
# ...

# %%
a.salem.quick_map()

# %%
t2_npp=t2.salem.transform(npp.data)
t2_npp.shape
# Out:
# (171, 231)

# %%
t2_npp.salem.quick_map()

# %%
t2.salem.quick_map()

# %%
import rioxarray as rio

# %%
t2_npp
# Out:
# <xarray.DataArray 'data' (south_north: 171, west_east: 231)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
# Coordinates:
#   * west_east    (west_east) float64 -3.45e+06 -3.42e+06 ... 3.42e+06 3.45e+06
#   * south_north  (south_north) float64 -2.55e+06 -2.52e+06 ... 2.52e+06 2.55e+06
# Attributes:
#     pyproj_srs:  +proj=lcc +lat_0=35.1800193786621 +lon_0=110 +lat_1=30 +lat_...

# %%
t2_npp.to_netcdf('/mnt/e/wrf_tibet/data/verify_data/t2.nc')

# %%
t2
# Out:
# <xarray.DataArray 'T2' (south_north: 171, west_east: 231)>
# array([[304.48935, 304.17194, 303.8652 , ..., 299.72238, 299.67676, 299.67642],
#        [304.5929 , 304.27466, 303.96472, ..., 299.79044, 299.7324 , 299.725  ],
#        [304.677  , 304.36002, 304.05444, ..., 299.8519 , 299.79553, 299.79175],
#        ...,
#        [295.1591 , 295.05795, 294.94656, ..., 279.3424 , 279.46832, 279.58963],
#        [294.5927 , 294.48532, 294.3883 , ..., 279.3704 , 279.4845 , 279.58588],
#        [294.14166, 293.9538 , 293.83746, ..., 279.4059 , 279.49664, 279.57605]],
#       dtype=float32)
# Coordinates:
#     XLAT         (south_north, west_east) float32 8.361839 ... 48.142765
#     XLONG        (south_north, west_east) float32 82.610504 ... 161.61536
#     XTIME        datetime64[ns] 2003-06-01T12:00:00
#   * west_east    (west_east) float64 -3.45e+06 -3.42e+06 ... 3.42e+06 3.45e+06
#   * south_north  (south_north) float64 -2.55e+06 -2.52e+06 ... 2.52e+06 2.55e+06
# Attributes:
# ...

# %%
import xarray as xr

# %%
nc=xr.open_dataset('/mnt/e/wrf_tibet/test/pre_test2003summer/wrfout_tibet_2003_summer_control')

# %%
nc['T2'][0].plot()

# %%
nc['T2'][0].to_netcdf('/mnt/e/wrf_tibet/data/verify_data/t2oo.nc')

# %%
t2.to_netcdf('/mnt/e/wrf_tibet/data/verify_data/t2o.nc')
